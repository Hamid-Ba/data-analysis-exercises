# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# شکلات‌های خوب‌تر
# </font>
# </h1>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# ویدا بعد از امتحان چند شکلات متوجه شد که به نظر او مزه‌ی شکلات‌های با امتیاز بالا فرق چندانی با امتیاز‌های پایین‌تر ندارد ولی با این وجود می‌تواند آن‌ها را با قیمت بسیار بالاتری بفروشد به همین دلیل از شما خواست تا شرکت‌های برتر شکلات را برای او پیدا کنید تا بتواند آن‌ها را جدا کرده و بفروشد.
# در این قسمت مراحل انجام این کار را با هم پیش می‌بریم.
#
# </font>
# </p>

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('chocolate_price.csv')
df.head()
# Out:
#     Company Specific Bean Origin  Review Date  Cocoa Percent Company Location  \
# 0  A. Morin          Agua Grande         2016           63.0           France
# 1  A. Morin                Kpime         2015           70.0           France
# 2  A. Morin               Atsane         2015           70.0           France
# 3  A. Morin                Akata         2015           70.0           France
# 4  A. Morin               Quilla         2015           70.0           France
#
#    Rating Bean Type Broad Bean Origin  price(100g)
# 0    75.0     Blend          Sao Tome     118125.0
# 1    55.0     Blend              Togo      96250.0
# 2    60.0     Blend              Togo     105000.0
# 3    70.0     Blend              Togo     122500.0
# 4    70.0     Blend              Peru     122500.0

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قسمت اول
# </font>
# </h2>
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# ابتدا، به ازای هر شرکت شکلات سازی، میانگین امتیاز شکلات‌ها را برای هر سال محاسبه کنید و مانند جدول زیر (اما برای تمامی سال‌ها) مقدار امتیاز متوسط هر شرکت در سال را ذخیره کنید.
# <br/>
# راهنمایی: بعد از استفاده از دستور <code>groupby</code> و محاسبه‌ی میانگین از دستور <code>unstack</code> استفاده کنید.
#
# </font>
# </p>
#
#
# <table dir=ltr align=center>
#
#
# <tr>
# <th>  </th>
# <th>2014</th>
# <th>2015</th>
# <th>2016</th>
# <th>2017</th>
#
# </tr>
#
# <tr>
# <td>company 1</td>
# <td>70.0</td>
# <td>63.75</td>
# <td>75</td>
# <td>NaN</td>
# </tr>
#
# <tr>
# <td>company 2</td>
# <td>NaN</td>
# <td>NaN</td>
# <td>NaN</td>
# <td>NaN</td>
# </tr>
#
#
# </table>

# %%
companies = df.groupby(['Company','Review Date'])['Rating'].mean().unstack()

# خطوط زیر برای استانداردسازی شکل جدول اعمال می‌شوند. برای جواب نهایی آن‌ها تغییر ندهید.
companies.columns.name=None
companies.index.name=None

companies.head()
# Out:
#                     2006  2007  2008  2009  2010  2011  2012       2013  2014  \
# A. Morin             NaN   NaN   NaN   NaN   NaN   NaN  72.5  66.363636  70.0
# AMMA                 NaN   NaN   NaN   NaN  77.5   NaN   NaN        NaN   NaN
# Acalli               NaN   NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# Adi                  NaN   NaN   NaN   NaN   NaN  55.0   NaN        NaN   NaN
# Aequare (Gianduja)   NaN   NaN   NaN  57.5   NaN   NaN   NaN        NaN   NaN
#
#                      2015  2016  2017
# A. Morin            63.75  75.0   NaN
# AMMA                  NaN   NaN   NaN
# Acalli              75.00   NaN   NaN
# Adi                   NaN   NaN   NaN
# Aequare (Gianduja)    NaN   NaN   NaN

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قسمت دوم
# </font>
# </h2>
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# برای محاسبه‌ی بهترین شرکت‌ها، نیازی به استفاده از مقدار همه‌ی سال‌ها نداریم بنابراین در متغیر <code>mean_ratings</code> میانگین ستون‌های جدول <code>companies</code> از سال ۲۰۱۲ به بعد به ازای هر کمپانی را ذخیره کنید.
# سپس در متغیر <code>best_ratings</code>، ۱۰ شرکت برتر به همراه میانگین رتبه‌ی آن‌ها را ذخیره کنید.
# <br>
#   دقت کنید که در مواردی که امتیاز شرکت‌ها برابر است، شرکت‌ها را به ترتیب الفبا انتخاب کنید.
# </font>
# </p>

# %%
over_2012 = companies[[i for i in companies.columns if i >= 2012]]
# over_2012 = over_2012.fillna(0)
over_2012.head()
# Out:
#                     2012       2013  2014   2015  2016  2017
# A. Morin            72.5  66.363636  70.0  63.75  75.0   NaN
# AMMA                 NaN        NaN   NaN    NaN   NaN   NaN
# Acalli               NaN        NaN   NaN  75.00   NaN   NaN
# Adi                  NaN        NaN   NaN    NaN   NaN   NaN
# Aequare (Gianduja)   NaN        NaN   NaN    NaN   NaN   NaN

# %%
mean_ratings = over_2012.mean(axis=1)
best_ratings = mean_ratings.copy()
best_ratings = best_ratings.reset_index()
# best_ratings.rename(columns={'index' : 'Company'},inplace=True)
best_ratings.sort_values(by=[0,'index'],ascending=[False,True],inplace=True)
best_ratings = best_ratings[:10]
# best_ratings = best_ratings.reset_index().drop(columns={'index'})
best_ratings
# Out:
#                        index          0
# 224                   Patric  80.000000
# 288   Tobago Estate (Pralus)  80.000000
# 302           Willie's Cacao  80.000000
# 152  L.A. Burdick (Felchlin)  77.500000
# 179                   Matale  77.500000
# 219                   Pacari  77.500000
# 293                 Valrhona  76.666667
# 2                     Acalli  75.000000
# 12                    Amedei  75.000000
# 14                 Askinosie  75.000000

# %%
# best_ratings = best_ratings.sort_index(ascending=True)
# best_ratings = best_ratings.sort_values(ascending=False)[:10]
# best_ratings = best_ratings.sort_index().sort_values(ascending=False)
# best_ratings

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قسمت سوم
# </font>
# </h2>
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در متغیر <code>chocolates_to_sell</code> شکلات‌هایی که شرکتشان بین ۱۰ شرکت برتر است را پیدا و ذخیره کنید.
# <br>
# •   از مرتب بودن ایندکس‌ها مطمئن شوید.
# <br>
# •	راهنمایی: برای بررسی وجود یک متغیر در یک لیست می‌توانید از تابع <code>isin</code> استفاده کنید.
#
# </font>
# </p>

# %%
chocolates_to_sell = df[df.Company.isin(best_ratings['index'])].reset_index().drop(columns=['index'])
chocolates_to_sell
# Out:
#                     Company                   Specific Bean Origin  \
# 0                    Acalli                Chulucanas, El Platanal
# 1                    Acalli                      Tumbes, Norandino
# 2                    Amedei               Piura, Blanco de Criollo
# 3                    Amedei                              Porcelana
# 4                    Amedei                                  Chuao
# 5                    Amedei                                Ecuador
# 6                    Amedei                                Jamaica
# 7                    Amedei                                Grenada
# 8                    Amedei                              Venezuela
# 9                    Amedei                             Madagascar
# 10                   Amedei                               Trinidad
# 11                   Amedei                          Toscano Black
# 12                   Amedei                          Toscano Black
# 13                   Amedei                          Toscano Black
# 14                Askinosie                                 Mababa
# 15                Askinosie                                 Cortes
# 16                Askinosie                     San Jose del Tambo
# 17  L.A. Burdick (Felchlin)                                 Brazil
# 18  L.A. Burdick (Felchlin)                                  Chuao
# 19  L.A. Burdick (Felchlin)                             Madagascar
# 20  L.A. Burdick (Felchlin)                               Bolivian
# 21                   Matale                            Somia, 2013
# 22                   Matale                                  Blend
# 23                   Pacari                Sierra Nevada, Tutu Iku
# 24                   Pacari                                 Garaua
# 25                   Pacari                                 Cumbia
# 26                   Pacari                               Montubia
# 27                   Pacari                                Tangara
# 28                   Pacari                                  Piura
# 29                   Pacari                        Nube- prototype
# 30                   Pacari                             Esmeraldas
# 31                   Pacari                                 Manabi
# 32                   Pacari                                    Raw
# 33                   Patric                        Signature Blend
# 34                   Patric                             Madagascar
# 35                   Patric           Rio Caribe, Paria Penninsula
#
#                    Bean Type   Broad Bean Origin  price(100g)
# 0                      Blend                Peru     131250.0
# 1                    Criollo                Peru     131250.0
# 2                      Blend                Peru     131250.0
# 3        Criollo (Porcelana)           Venezuela     140000.0
# 4                 Trinitario           Venezuela     175000.0
# 5                 Trinitario             Ecuador     105000.0
# 6                 Trinitario             Jamaica     105000.0
# 7                 Trinitario             Grenada     122500.0
# 8   Trinitario (85% Criollo)           Venezuela     131250.0
# 9   Trinitario (85% Criollo)          Madagascar     140000.0
# 10                Trinitario            Trinidad     122500.0
# 11                     Blend               Other     110250.0
# 12                     Blend               Other     175000.0
# 13                     Blend               Other     132000.0
# 14                Trinitario            Tanzania     127500.0
# 15                Trinitario            Honduras     131250.0
# 16        Forastero (Arriba)             Ecuador     105000.0
# 17                     Blend              Brazil     140000.0
# 18                Trinitario           Venezuela     127500.0
# 19                Trinitario          Madagascar     112000.0
# 20                     Blend             Bolivia     102000.0
# 21                Trinitario          Madagascar     136000.0
# 22                Trinitario   PNG, Vanuatu, Mad     131250.0
# 23                     Blend            Colombia     140000.0
# 24                     Blend             Ecuador     113750.0
# 25                     Blend             Ecuador     122500.0
# 26                     Blend             Ecuador     131250.0
# 27                     Blend             Ecuador     140000.0
# 28                     Blend                Peru     140000.0
# 29                     Blend             Ecuador     122500.0
# 30        Forastero (Arriba)             Ecuador      75000.0
# 31        Forastero (Arriba)             Ecuador      89375.0
# 32        Forastero (Arriba)             Ecuador     122500.0
# 33                     Blend               Other     131250.0
# 34                Trinitario          Madagascar     117250.0
# 35                Trinitario           Venezuela     122500.0
# 36                Trinitario          Madagascar     140000.0
# 37                     Blend                Peru     134000.0
# 38                Trinitario              Tobago     140000.0
# 39                     Blend                Peru     126000.0
# 40                     Blend               Other     122500.0
# 41                     Blend  Dominican Republic     112000.0
# 42                     Blend           Venezuela     138000.0
# 43                     Blend               Other      91000.0
# 44                   Criollo           Venezuela     128000.0
# 45                     Blend  Dominican Republic     120000.0
# 46                     Blend             Ecuador     123750.0
# 47                 Forastero               Ghana     119000.0
# 48                Trinitario           Venezuela     121875.0
# 49       Criollo, Trinitario          Madagascar     128000.0
# 50       Criollo (Porcelana)           Venezuela     104000.0
# 51                Trinitario           Carribean      99000.0
# 52       Criollo, Trinitario       South America     140000.0
# 53                Trinitario            Trinidad      80000.0
# 54       Criollo (Porcelana)           Venezuela      96000.0
# 55                Trinitario          Madagascar     112000.0
# 56                     Blend            Colombia     140000.0
# 57                     Blend           Indonesia     129375.0
# 58                     Blend                Peru     105000.0

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قسمت چهارم
# </font>
# </h2>
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در نهایت مجموع قیمت این شکلات‌ها را در متغیر <code>price</code> ذخیره کنید تا میزان درآمد ویدا از آن‌ها مشخص شود.
# </font>
# </p>

# %%
priceSum = chocolates_to_sell['price(100g)'].sum()
priceSum
# Out:
# 7282125.0

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>

# %%
import zlib
import zipfile


def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)


companies.to_csv('companies.csv',index = True)
chocolates_to_sell.to_csv('chocolates_to_sell.csv',index = True)
mean_ratings.to_csv("mean_ratings.csv", index = True)
best_ratings.to_csv("best_ratings.csv", index = True)

np.savez("answers.npz" ,priceSum = priceSum)
file_names = ["answers.npz", "project1_3.ipynb","chocolates_to_sell.csv","companies.csv","mean_ratings.csv", "best_ratings.csv"]
compress(file_names)
# Out:
# File Paths:
# ['answers.npz', 'project1_3.ipynb', 'chocolates_to_sell.csv', 'companies.csv', 'mean_ratings.csv', 'best_ratings.csv']
